# %% [markdown]
# <h1>Table des matières<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Solutions" data-toc-modified-id="Solutions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Solutions</a></span></li><li><span><a href="#Démonstration" data-toc-modified-id="Démonstration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Démonstration</a></span><ul class="toc-item"><li><span><a href="#Import-des-librairies" data-toc-modified-id="Import-des-librairies-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import des librairies</a></span></li><li><span><a href="#Prétraitement-des-données" data-toc-modified-id="Prétraitement-des-données-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Prétraitement des données</a></span><ul class="toc-item"><li><span><a href="#Chemins-d'accès-à-la-source-et-à-la-destination" data-toc-modified-id="Chemins-d'accès-à-la-source-et-à-la-destination-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Chemins d'accès à la source et à la destination</a></span></li><li><span><a href="#Instanciation-d'une-pipeline-du-générateur-de-données" data-toc-modified-id="Instanciation-d'une-pipeline-du-générateur-de-données-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Instanciation d'une pipeline du générateur de données</a></span></li><li><span><a href="#Réglage-des-paramètres-de-traitement-et-démarrage-du-traitement" data-toc-modified-id="Réglage-des-paramètres-de-traitement-et-démarrage-du-traitement-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Réglage des paramètres de traitement et démarrage du traitement</a></span></li></ul></li><li><span><a href="#Créer-un-générateur-pour-l'entrainement-et-l'évaluation" data-toc-modified-id="Créer-un-générateur-pour-l'entrainement-et-l'évaluation-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Créer un générateur pour l'entrainement et l'évaluation</a></span><ul class="toc-item"><li><span><a href="#Données-d’entrainement,-de-test-et-de-validation" data-toc-modified-id="Données-d’entrainement,-de-test-et-de-validation-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Données d’entrainement, de test et de validation</a></span></li><li><span><a href="#Augmentation-et-génération-des-données" data-toc-modified-id="Augmentation-et-génération-des-données-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Augmentation et génération des données</a></span></li><li><span><a href="#Visualiser-le-jeu-de-données" data-toc-modified-id="Visualiser-le-jeu-de-données-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Visualiser le jeu de données</a></span></li></ul></li><li><span><a href="#Démonstration-de-création-d'un-modèle-:-FCN-avec-augmentation" data-toc-modified-id="Démonstration-de-création-d'un-modèle-:-FCN-avec-augmentation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Démonstration de création d'un modèle : FCN avec augmentation</a></span></li><li><span><a href="#Entraînement-du-modèle" data-toc-modified-id="Entraînement-du-modèle-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Entraînement du modèle</a></span></li><li><span><a href="#Enregistrement-du-modèle" data-toc-modified-id="Enregistrement-du-modèle-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Enregistrement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-la-courbe-d'apprentissage" data-toc-modified-id="Visualisation-de-la-courbe-d'apprentissage-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Visualisation de la courbe d'apprentissage</a></span></li><li><span><a href="#Visualisation-de-la-matrice-de-confusion" data-toc-modified-id="Visualisation-de-la-matrice-de-confusion-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Visualisation de la matrice de confusion</a></span></li><li><span><a href="#Faire-des-prédictions-et-les-visualiser" data-toc-modified-id="Faire-des-prédictions-et-les-visualiser-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Faire des prédictions et les visualiser</a></span></li><li><span><a href="#Traiter-une-séquence-d'images,-les-enregistrer-sur-le-disque,-et-générer-une-vidéo-à-partir-de-celles-ci" data-toc-modified-id="Traiter-une-séquence-d'images,-les-enregistrer-sur-le-disque,-et-générer-une-vidéo-à-partir-de-celles-ci-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Traiter une séquence d'images, les enregistrer sur le disque, et générer une vidéo à partir de celles-ci</a></span></li></ul></li><li><span><a href="#Résultats-des-différents-pipelines" data-toc-modified-id="Résultats-des-différents-pipelines-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Résultats des différents pipelines</a></span><ul class="toc-item"><li><span><a href="#FCN-8s" data-toc-modified-id="FCN-8s-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>FCN-8s</a></span><ul class="toc-item"><li><span><a href="#FCN8-s-sans-augmentation" data-toc-modified-id="FCN8-s-sans-augmentation-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>FCN8-s sans augmentation</a></span></li><li><span><a href="#FCN8-s-avec-augmentation" data-toc-modified-id="FCN8-s-avec-augmentation-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>FCN8-s avec augmentation</a></span></li></ul></li><li><span><a href="#U-Net" data-toc-modified-id="U-Net-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>U-Net</a></span><ul class="toc-item"><li><span><a href="#U-Net-sans-augmentation" data-toc-modified-id="U-Net-sans-augmentation-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>U-Net sans augmentation</a></span></li><li><span><a href="#U-Net-avec-augmentation" data-toc-modified-id="U-Net-avec-augmentation-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>U-Net avec augmentation</a></span></li></ul></li><li><span><a href="#SegNet" data-toc-modified-id="SegNet-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SegNet</a></span><ul class="toc-item"><li><span><a href="#SegNet-sans-augmentation" data-toc-modified-id="SegNet-sans-augmentation-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>SegNet sans augmentation</a></span></li><li><span><a href="#🏆-SegNet-avec-augmentation" data-toc-modified-id="🏆-SegNet-avec-augmentation-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>🏆 SegNet avec augmentation</a></span></li></ul></li><li><span><a href="#Résulat" data-toc-modified-id="Résulat-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Résulat</a></span></li></ul></li><li><span><a href="#Déploiement" data-toc-modified-id="Déploiement-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Déploiement</a></span></li><li><span><a href="#Note-technique" data-toc-modified-id="Note-technique-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Note technique</a></span></li><li><span><a href="#Conclusion-et-axes-d’amélioration" data-toc-modified-id="Conclusion-et-axes-d’amélioration-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Conclusion et axes d’amélioration</a></span></li></ul></div>

# %% [markdown]
# # Future Vision Transport

# %% [markdown]
# ![logo](data/images/logo.png "Futur Vision Transport")

# %% [markdown]
# **Future Vision Transport** est une entreprise qui conçoit des systèmes embarqués de vision par ordinateur pour les véhicules autonomes.
#
# L’objectif de ce projet est de concevoir un modèle de segmentation d’images répondant aux besoins des équipes de traitement des images et de système de décision.
#
# L’équipe de **traitement des images** :
#
# - Utilise le jeu de donnée « [Cityscapes](https://www.cityscapes-dataset.com/) », une banque de données d'images de paysages de villes. Le jeu de données se compose de 32 catégories et seulement **les 8 catégories principales sont nécessaires.**
#
# - Informe que les images en entrée peuvent changer. Le système d’acquisition n’est pas stable. _À détailler : y a-t-il des déformations d’images ou bien des résolutions différentes ?_
#
# - Le volume de données sera vite important.
#
# L’équipe en charge du **système de décision**
#
# - Souhaite une API simple à utiliser.
#
# - Une interface web sous Flask
#
# Les livrables seront :
#
# 1. Un ensemble de scripts déployé sur Azure permettant l’exécution du pipeline complet
#
# 2. Une API Flask déployée sur Azure
#
# 3. Une note technique

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note : </b> Ce notebook a pour but d'expliquer le choix des solutions pour répondre à la demande.
#
# Nous commencerons par présenter la solution proposée avant de passer à la démonstration et de conclure sur la note technique. </div>

# %% [markdown]
# <img src="data/images/solution.png" width="150">
#
# ## Solutions
#
# Pour répondre à la demande de l’équipe de traitement des images :
#
# - **Pour travailler avec les 8 catégories principales** -> nous allons forker les scripts officiels du jeu de données Cityscapes à partir du dépôt [cityscapesScripts](https://github.com/mcordts/cityscapesScripts). Puis nous y ajouterons quelques dictionnaires et tableaux de conversion utiles comme variables globales qui répondront au besoin. Les ajouts sont visibles dans [ce dépôt](https://github.com/Abdess/cityscapesScripts/blob/master/cityscapesscripts/helpers/labels_bdga.py#L223)
#
#
#
# <img src="data/images/capture1.png" width="500">
#
# - **Pour faire face aux** :
#
# 1. **changements des images en entrées**
#
# 2. **de l’instabilité du système d’acquisition**
#
# 3. **et du volume de données important**
#
# Nous avons développé _un script tout en un_ appelé [batchdatagenaug.py](https://github.com/Abdess/cityscapesScripts/blob/master/cityscapesscripts/preparation/batchdatagenaug.py) pour "**Batch** **Data** **Gen**erator and **Aug**mentation". La documentation technique du script est [disponible ici](data/doc/batchdatagenaug.html).
#
# <img src="data/UML/draft_batchdatagenaug.jpg" width="300">
#
# En plus de permettre, une augmentation des images, il permet aussi d’apporter une solution à la **1re** et à la **2e** contrainte.
# En ce qui concerne le **3e** point, le script **allège** la charge du processus de traitement d'images avec une gestion des fichiers par lots de sorte à ne pas saturer la mémoire vive et le processeur. Le script supporte le **multithreading**, ce qui accélère considérablement l'exécution de la tâche.
#
# <img src="data/images/capture3.png" width="400">
#
# Pour répondre à la demande de l’équipe en charge du **système de décision**, il suffira de fournir une API qui ne demandera en entrée que l’identifiant d’une image. Une interface graphique sous flask permettra d’utiliser l’API.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 1/18 : un générateur de données permettant le traitement des images sur plusieurs cœurs de calcul a été développé et testé.</p>
#     <p>✅ 2/18 : le générateur de données a été rédigé sous forme de classe python.</p>
#     <p>✅ 3/18 : le script du générateur de données est entièrement automatisé.</p>
# </div>

# %% [markdown]
# <img src="data/images/demo.png" width="150">
#
# ## Démonstration
#
# Cette section présente la manière de travailler avec différentes approches de segmentations avec le [jeu de données Cityscapes](https://www.cityscapes-dataset.com/) pour entrainer les modèles avec les scripts. La configuration décrite est applicable à des jeux de données arbitraires.
#
# Dans les sections suivantes, nous aborderons pas à pas l'**entrainement**, l'**évaluation**, la **prédiction** et la **visualisation**.

# %% [markdown]
# ### Import des librairies

# %%
# Installation de l'ensemble de scripts contenant nos ajouts

# !pip install git+https://github.com/Abdess/cityscapesScripts.git

# %%
# Générateur et augmentation des données
from cityscapesscripts.preparation.batchdatagenaug import BatchDataGenAug
from cityscapesscripts.helpers.visualization_utils import \
    print_segmentation_onto_image, create_video_from_images
# Variable d'exportation des 8 catégories principale
from cityscapesscripts.helpers.labels_bdga import IDS_TO_CATEGORYIDS_ARRAY, \
    COLORS_CAT_TO_IDS_DICT

from math import ceil
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Prétraitement des données
#
# Nous allons effectuer certaines transformations sur toutes les images (aussi sur les images de référence) d'un ou plusieurs ensembles de données, puis enregistrer les résultats dans un répertoire cible. Ce faisant, le générateur reproduit la même hiérarchie de répertoires que le répertoire source dans le répertoire cible.
#
# Si des données de vérité terrain sont fournies, elles sont traitées de manière cohérente avec les images respectives.

# %% [markdown]
# #### Chemins d'accès à la source et à la destination
#
# Nous allons :
#
# - Définir les chemins d'accès à un nombre arbitraire de jeux de données sources que l'on souhaite traiter.
# - Définir un répertoire d'exportation, c'est-à-dire le répertoire dans lequel on souhaite exporter les données traitées.
# - Définir le répertoire racine des jeux de données à traiter. Le générateur reproduira la hiérarchie des répertoires qu'il trouve dans ce répertoire racine dans le répertoire d'exportation.

# %%
# Les répertoires qui contiennent les images train, val et test
train_images = 'data/cityscapes/leftImg8bit/train/'
val_images = 'data/cityscapes/leftImg8bit/val/'
test_images = 'data/cityscapes/leftImg8bit/test/'

# Les répertoires qui contiennent les images de vérité terrain (train et val)
train_gt = 'data/cityscapes/gtFine/train/'
val_gt = 'data/cityscapes/gtFine/val/'

# Définit les éléments ci-dessus à passer au constructeur du `BatchDataGenAug`.
image_dirs = [train_images, val_images]
ground_truth_dirs = [train_gt, val_gt]

# Le répertoire dans lequel les images traitées doivent être exportées.
export_dir = 'data/cityscapes_small/'
# Le répertoire racine du jeu de données.
root_dir = 'data/cityscapes/'

# %% [markdown]
# <div class="alert alert-block alert-info">
# ✅ 4/18 : la cible a été identifiée
# </div>

# %% [markdown]
# #### Instanciation d'une pipeline du générateur de données
#
# Nous commençons donc par créer une instance de BatchDataGenAug et nous lui passons une liste de répertoires contenant les images avec les images de vérité terrain que nous souhaitons traiter.

# %%
offline_processor = BatchDataGenAug(image_dirs=image_dirs,
                                    image_file_extension='png',
                                    ground_truth_dirs=ground_truth_dirs,
                                    image_name_split_separator='leftImg8bit',
                                    ground_truth_suffix='gtFine_labelIds',
                                    check_existence=True,
                                    root_dir=root_dir,
                                    export_dir=export_dir)

num_files = offline_processor.get_num_files()
print("Nombre total de fichiers dans tous les jeux de données :", num_files)
# Out:
# Nombre total de fichiers dans tous les jeux de données : 3475

# %% [markdown]
# #### Réglage des paramètres de traitement et démarrage du traitement
#
# Il suffit d'appeler ***process_all()*** sur l'instance de **BatchGenerator** avec les paramètres souhaités.
#
# Dans cet exemple, nous souhaitons faire deux choses avec les données :
#
# 1. Les ID des classes de segmentation dans les images de vérité de terrain Cityscapes vont de 0 à 33 et contiennent un grand nombre de classes non pertinentes qui sont ignorées dans l'évaluation. Donc, nous allons transmettre une carte sous la forme d'un dictionnaire pour en conserver les 8 principales, cela va ralentir le traitement. Lorsque le modèle a été formé, il est possible de rétablir les ID de classe d'origine de la même manière.
#
# 2. Les images de l'ensemble de données Cityscapes ont une taille de (1024, 2048). Il serait souhaitable que le modèle soit entrainé sur ces images en taille réelle, mais cela est trop important pour le GPU. En conséquence, nous allons réduire la taille des images d'un facteur 16 à (256, 512).
#
# Consultez [la documentation du script](data/doc/batchdatagenaug.html) pour plus de détails sur les autres transformations disponibles dans BatchDataGenAug.

# %%
offline_processor.process_all(
    convert_colors_to_ids=False,
    # Convertit les identifiants de classe en d'autres.
    convert_ids_to_ids=IDS_TO_CATEGORYIDS_ARRAY,
    convert_to_one_hot=False,
    void_class_id=None,
    random_crop=False,
    crop=False,
    # Redimensionne les images
    resize=(256, 512),
    brightness=False,
    flip=False,
    translate=False,
    scale=False,
    gray=False,
    # Enregistre les images traitées sur le disque.
    to_disk=True)
# Out:
# Traitement des images: 100%|███████████████████████████████████████████████████████| 3475/3475 [16:01<00:00,  3.61it/s]

# %% [markdown]
# ### Créer un générateur pour l'entrainement et l'évaluation
#
# Les modèles ont besoin d'un générateur qui les alimente avec des lots d'images et les images de référence (ground truth) correspondantes. Idéalement, nous voulons deux générateurs, un qui sert les données d'un jeu de données d'entraînement et un autre qui sert les données d'un jeu de données de validation. Le jeu de données Cityscapes fournit déjà une partie des données pour nous, donc nous allons nous en tenir à cela.
#
# Afin de s'entraîner avec le jeu de données Cityscapes, la seule chose que nous devons vraiment faire ici est de définir les chemins appropriés vers le jeu de données sur notre machine, pour d'autres jeux de données, vous devrez passer des valeurs différentes au constructeur `BatchDataGenAug`, consultez la documentation pour plus de détails.
#
# Note : Si vous devez prétraiter votre jeu de données, par exemple pour changer la taille de l'image ou pour convertir les étiquettes de classe de segmentation, je vous suggère de le faire hors ligne.

# %% [markdown]
# #### Données d’entrainement, de test et de validation

# %%
# Définir les chemins vers les images.
train_images = 'data/cityscapes_small/leftImg8bit/train/'
val_images = 'data/cityscapes_small/leftImg8bit/val/'
test_images = 'data/cityscapes_small/leftImg8bit/test/'

# Définir les chemins vers les images ground truth.
train_gt = 'data/cityscapes_small/gtFine/train/'
val_gt = 'data/cityscapes_small/gtFine/val/'

# Mettre les chemins vers les jeux de données dans des listes, parce que
# c'est ce que `BatchDataGenAug` exige comme entrée.
train_image_dirs = [train_images]
train_ground_truth_dirs = [train_gt]
val_image_dirs = [val_images]
val_ground_truth_dirs = [val_gt]

# %%
# Définir le nombre de classes de segmentation.
num_classes = 8

train_dataset = BatchDataGenAug(image_dirs=train_image_dirs,
                                image_file_extension='png',
                                ground_truth_dirs=train_ground_truth_dirs,
                                image_name_split_separator='leftImg8bit',
                                ground_truth_suffix='gtFine_labelIds',
                                check_existence=True,
                                num_classes=num_classes)

val_dataset = BatchDataGenAug(image_dirs=val_image_dirs,
                              image_file_extension='png',
                              ground_truth_dirs=val_ground_truth_dirs,
                              image_name_split_separator='leftImg8bit',
                              ground_truth_suffix='gtFine_labelIds',
                              check_existence=True,
                              num_classes=num_classes)

num_train_images = train_dataset.get_num_files()
num_val_images = val_dataset.get_num_files()

print("Taille du jeu de données d'entraînement :", num_train_images, "images")
print("Taille du jeu de données de validation :", num_val_images, "images")
# Out:
# Taille du jeu de données d'entraînement : 2975 images
# Taille du jeu de données de validation : 500 images

# %% [markdown]
# <div class="alert alert-block alert-info">
# ✅ 5/18 : la séparation du jeu de données en jeu d’entraînement et en jeu de test a été réalisée
# </div>

# %% [markdown]
# #### Augmentation et génération des données
#
# Ici, vous pouvez choisir vos paramètres d’augmentation et de génération des données. Il est possible de rogner, redimensionner, régler la luminosité, les couleurs, etc.

# %%
# Définir la taille du lot.
# Nous utiliserons la même taille de lot pour les deux générateurs ici.
batch_size = 4

train_generator = train_dataset.generate(batch_size=batch_size,
                                         convert_colors_to_ids=False,
                                         convert_ids_to_ids=False,
                                         convert_to_one_hot=True,
                                         void_class_id=None,
                                         random_crop=False,
                                         crop=False,
                                         resize=False,
                                         brightness=False,
                                         flip=0.5,
                                         translate=False,
                                         scale=False,
                                         gray=False,
                                         to_disk=False,
                                         shuffle=True)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     convert_colors_to_ids=False,
                                     convert_ids_to_ids=False,
                                     convert_to_one_hot=True,
                                     void_class_id=None,
                                     random_crop=False,
                                     crop=False,
                                     resize=False,
                                     brightness=False,
                                     flip=False,
                                     translate=False,
                                     scale=False,
                                     gray=False,
                                     to_disk=False,
                                     shuffle=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 6/18 : il n’y a pas de fuite d’information entre les deux jeux de données (entraînement et test)</p>
#     <p>✅ 7/18 : au moins trois techniques d’augmentation des données ont été utilisées (ex : rotation, changement d’échelle, ajout de bruit,…)</p>
# </div>

# %%
# Afficher quelques diagnostics pour s'assurer que nos lots ne sont pas
# vides et qu'il ne faut pas une éternité pour les générer.
start_time = time.time()
images, gt_images = next(train_generator)
print('Temps pour générer un lot : {:.3f} seconds'.format(time.time() -
                                                          start_time))
print('Nombre d\'images générées :', len(images))
print('Nombre d\'images de référence générées:', len(gt_images))
# Out:
# Temps pour générer un lot : 0.115 seconds
# Nombre d'images générées : 4
# Nombre d'images de référence générées: 4

# %% [markdown]
# #### Visualiser le jeu de données
#
# Visualisons l'ensemble des données pour mieux comprendre les données de base.

# %%
# Générer des lots à partir du train_generator où le ground truth n'est
# pas convertie en one-hot afin que nous puissions les afficher sous
# forme d'images.
example_generator = train_dataset.generate(batch_size=batch_size,
                                           convert_to_one_hot=False)

# %%
# Générer un lot.
example_images, example_gt_images = next(example_generator)

# %%
i = 0  # Choisir l'échantillon du lot à afficher ci-dessous.

figure, cells = plt.subplots(1, 2, figsize=(16, 8))
cells[0].imshow(example_images[i])
cells[1].imshow(example_gt_images[i])

# %%
plt.figure(figsize=(16, 8))
plt.imshow(example_gt_images[i])

# %% [markdown]
# ### Démonstration de création d'un modèle : FCN avec augmentation
#
# On instancie le pipeline du modèle que l'on souhaite créer (**U-Net**, **SegNet** ou **FCN**)

# %%
import cityscapes_tensorflow as cstf

model = cstf.FCN(num_classes=num_classes) # ou UNET ou SEGNET
# Out:
# TensorFlow Version : 2.8.0

# %% [markdown]
# ### Entraînement du modèle
#
# Maintenant, il suffit d'appeler la méthode `train()` pour entraîner le modèle. Référez-vous à la documentation pour plus de détails sur tous les arguments, mais voici quelques notes :
#
# 1. Vous devrez passer une fonction de planification du taux d'apprentissage, même si elle est simple. Cette fonction prend en entrée un entier (le pas d'apprentissage) et retourne un flottant (le taux d'apprentissage). Je vais simplement définir une fonction de pas simple ci-dessous.
# 2. Passez le(s) générateur(s) que nous avons instancié(s) ci-dessus. Notez qu'il y a deux arguments qui prennent un générateur en entrée, `train_generator` et `val_generator`, où le dernier est optionnel.

# %%
epochs = 6  # Définir le nombre d'époques pour l'entraînement.


# Définir une fonction de planification du taux d'apprentissage à passer
# à la méthode `train()`.
def learning_rate_schedule(step):
    if step <= 10000:
        return 0.0001
    elif 10000 < step <= 20000:
        return 0.00001
    elif 20000 < step <= 40000:
        return 0.000003
    else:
        return 0.000001


model.train(train_generator=train_generator,
            epochs=epochs,
            steps_per_epoch=ceil(num_train_images / batch_size),
            learning_rate_schedule=learning_rate_schedule,
            keep_prob=0.5,
            l2_regularization=0.0,
            eval_dataset='val',
            eval_frequency=2,
            val_generator=val_generator,
            val_steps=ceil(num_val_images / batch_size),
            metrics={'loss', 'mean_iou', 'accuracy'},
            save_during_training=True,
            save_dir='cityscapes_model',
            save_best_only=True,
            save_tags=['default'],
            save_name='(batch-size-4)',
            save_frequency=2,
            saver='saved_model',
            monitor='loss',
            record_summaries=True,
            summaries_frequency=10,
            summaries_dir='data/logs',
            summaries_name='configuration_01',
            training_loss_display_averaging=3)
# Out:
# Périphérique GPU par défaut : /gpu:0
# ...
# Évaluation sur le jeu de données d'entrainement : 100%|██████████| 125/125 [00:47<00:00,  2.66it/s]
# loss: 0.8327  mean_iou: 0.2487  accuracy: 0.8047
# Nouvelle meilleure valeur loss, sauvegarde du modèle.
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'cityscapes_model/saved_model_(batch-size-4)_(globalstep-1488)_(trainloss-0.6108)_(eval_on_val_dataset)_(loss-0.8327)_(mean_iou-0.2487)_(accuracy-0.8047)/saved_model.pb'
# ...
# Évaluation sur le jeu de données d'entrainement : 100%|██████████| 125/125 [00:43<00:00,  2.90it/s]
# loss: 0.7014  mean_iou: 0.2645  accuracy: 0.8124
# Nouvelle meilleure valeur loss, sauvegarde du modèle.
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 8/18 : une métrique adaptée à la problématique métier a été choisie et sert à évaluer la performance des modèles (ex : coefficient Sørensen-Dice de similarité)</p>
#     <p>✅ 9/18 : Au moins un des hyperparamètres du modèle choisi a été optimisé (ex : le choix de la fonction loss)</p>
# </div>

# %% [markdown]
# ### Enregistrement du modèle
#
# J'ai déjà défini la méthode `train()` ci-dessus pour sauvegarder le modèle sur le disque pendant l'entraînement, donc le modèle a déjà été sauvegardé (potentiellement plusieurs fois) et il n'est pas nécessaire de le sauvegarder manuellement, voici l'appel de méthode.

# %%
model.save(model_save_dir='data/models',
           saver='saved_model',
           tags=['default'],
           name='(batch-size-4)',
           include_global_step=True,
           include_last_training_loss=True,
           include_metrics=True,
           force_save=False)
# Out:
# Abandon : Rien à sauvegarder, aucun entrainement n'a été effectuée depuis la dernière sauvegarde du modèle.

# %% [markdown]
# ### Évaluation du modèle
#
# J'ai déjà défini la méthode `train()` ci-dessus pour évaluer le modèle toutes les quelques époques pendant l'entraînement, mais vous pouvez évaluer le modèle explicitement comme montré ci-dessous. Il y a actuellement trois métriques intégrées : (1) l'intersection moyenne sur l'union (MeanIoU), qui est probablement la métrique la plus importante pour les modèles de segmentation sémantique, (2) la précision (Pixel Accuracy), qui mesure simplement le ratio de pixels d'images qui ont été classés correctement, et (3) la perte, qui est simplement la sortie de la fonction de perte. Vous pouvez évaluer le modèle sur n'importe quel sous-ensemble.

# %%
model.evaluate(data_generator=val_generator,
               metrics={'loss', 'mean_iou', 'accuracy'},
               num_batches=ceil(num_val_images / batch_size),
               l2_regularization=0.0,
               dataset='val')
# Out:
# Évaluation : 100%|██████████| 125/125 [00:35<00:00,  3.57it/s]
# loss: 0.6902  mean_iou: 0.2712  accuracy: 0.8298

# %% [markdown]
# ### Visualisation de la courbe d'apprentissage

# %%
# %tensorboard --logdir data/logs

# %% [markdown]
# ### Visualisation de la matrice de confusion

# %%
import cityscapesscripts.evaluation.evalPixelLevelSemanticLabeling as cityscapes_eval

cityscapes_eval.getPrediction(val_gt)
# Out:
# categories       IoU      nIoU
# --------------------------------
# flat          : 0.247      nan
# construction  : 0.277      nan
# object        : 0.280      nan
# nature        : 0.287      nan
# sky           : 0.264      nan
# human         : 0.276      nan
# vehicle       : 0.268      nan
# --------------------------------
# Score Average : 0.271      nan
# --------------------------------

# %% [markdown]
# ### Faire des prédictions et les visualiser

# %%
images, labels = next(val_generator)

# %%
n = 3  # Choisir l'image du lot à visualiser.

# Faire une prédiction.
prediction = model.predict([images[n]], argmax=False)

# Afficher la segmentation prédite sur l'image.
segmented_image = print_segmentation_onto_image(
    images[n], prediction, color_map=TRAINIDS_TO_RGBA_DICT)

plt.figure(figsize=(20, 14))
plt.imshow(segmented_image)

# %% [markdown]
# ### Traiter une séquence d'images, les enregistrer sur le disque, et générer une vidéo à partir de celles-ci
#
# Au cas où cela vous serait utile, avec la méthode ci-dessous, vous pouvez simplement laisser le modèle exécuter des prédictions sur toutes les images d'un répertoire donné, imprimer les segmentations prédites sur celles-ci, et en enregistrer une copie sur le disque.

# %%
model.predict_and_save(
    results_dir='video_images',
    images_dir='data/Cityscapes_small/leftImg8bit/demoVideo/stuttgart_00',
    color_map=TRAINIDS_TO_RGBA_DICT,
    resize=False,
    image_file_extension='png',
    include_unprocessed_image=True,
    arrangement='vertical')
# Out:
# Les images segmentées seront enregistrées dans "video_images"
# Traitement des images : 100%|██████████| 599/599 [01:02<00:00,  9.66it/s]

# %% [markdown]
# Faisons une vidéo à partir des prédictions ci-dessus :

# %%
create_video_from_images(video_output_name='video',
                         image_input_dir='video_images',
                         frame_rate=30.0,
                         image_file_extension='png')
# Out:
# [MoviePy] >>>> Building video video.mp4
# [MoviePy] Writing video video.mp4
# 100%|██████████| 600/600 [00:05<00:00, 120.01it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: video.mp4

# %% [markdown]
# <img src="data/images/prediction.gif">

# %% [markdown]
# ## Résultats des différents pipelines
#
# Le choix des modèles est inspiré des travaux de Divam Gupta : https://github.com/divamgupta/image-segmentation-keras/

# %% [markdown]
# ### FCN-8s
#
# <img src="data/images/fcn.png" width='400'>
#
# Le pipeline du réseau FCN est une extension du CNN classique. Contrairement au CNN, les FCNs ont seulement des couches convolutionnelles et de mise en commun qui leur donnent la capacité de faire des prédictions sur des entrées de taille arbitraire.
#
# Un problème dans ce FCN spécifique est qu'en se propageant à travers plusieurs couches de convolution et de mise en commun alternées, la résolution des cartes de caractéristiques de sortie est sous-échantillonnée. Par conséquent, les prédictions directes du FCN sont généralement de faible résolution, ce qui donne des limites d'objets relativement floues. Diverses approches plus avancées basées sur le FCN ont été proposées pour résoudre ce problème, notamment SegNet, qui sera testé par la suite
#
# <img src="data/images/fcn8s.png" width="700">
#
# Dans cette approche, nous avons fait le choix du FCN-8s qui va suréchantillonné 8 fois l'image en sortie.
#
# <img src="data/images/fcn8s_bench.png">
#
# Le résultat de FCN-32s est très approximatif en raison de la perte d'informations de localisation, tandis que FCN-8s obtient le meilleur résultat.
#
# (source : https://doi.org/10.48550/arXiv.1411.4038)

# %% [markdown]
# #### FCN8-s sans augmentation
#
# **Paramètres** :
#
# - Fonction d'activation : ReLu
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : 83.68%
# - Mean IoU : 30.13%
# - Temps d'entrainement : **17m05s**
#
# <img src="data/images/fcn8s_no-aug.png">

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 10/18 : la performance d’un modèle de référence a été évaluée (UnetMini par exemple) et sert de comparaison pour évaluer la performance des modèles plus complexes</p>
#     <p>✅ 11/18 : Hormis la métrique choisie, au moins un autre indicateur a été calculé pour comparer les modèles (ex : le temps nécessaire pour l’entraînement du modèle)</p>
# </div>

# %% [markdown]
# #### FCN8-s avec augmentation
#
# **Paramètres** :
#
# - Fonction d'activation : ReLu
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : **84.02%**
# - Mean IoU : **30.21%**
# - Temps d'entrainement : 20m18s
#
# <img src="data/images/fcn8s_with-aug.png">

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 12/18 : l’utilisation des techniques d’augmentation ont permis d’améliorer la performance du modèle de Deep Learning</p>
# </div>

# %% [markdown]
# ### U-Net
#
# <img src="data/images/U-Net.png" width='500'>
#
# Le réseau U-net s'appuie sur le FCN décrit ci-dessus. Il se compose également d'un encodeur qui réduit l'échantillonnage de l'image d'entrée à une carte de caractéristiques et d'un décodeur qui augmente l'échantillonnage de la carte de caractéristiques à la taille de l'image d'initial en utilisant des couches de déconvolution apprises.
#
# La principale contribution de l'architecture U-Net réside dans les connexions de raccourci. Nous avons vu plus haut dans FCN que puisque nous sous-échantillonnons une image dans le cadre de l'encodeur, nous avons perdu beaucoup d'informations qui ne peuvent pas être facilement récupérées dans la partie encodeur. FCN tente de résoudre ce problème en prenant des informations dans les couches de mise en commun avant la couche de caractéristiques finale.
#
# U-Net propose une nouvelle approche pour résoudre ce problème de perte d'information. Il propose d'envoyer des informations à chaque couche d'échantillonnage ascendante dans le décodeur à partir de la couche d'échantillonnage descendante correspondante dans le décodeur, comme on peut le voir dans l'illustration ci-dessus. Puisque les couches au début de l'encodeur auraient plus d'informations, elles soutiendraient l'opération d'échantillonnage ascendant du décodeur en fournissant des détails fins correspondant aux images d'entrée, ce qui améliorerait considérablement les résultats.
#
# (source : https://arxiv.org/abs/1505.04597)

# %% [markdown]
# #### U-Net sans augmentation
#
# 🥈 **Meilleur temps**
#
# **Paramètres** :
#
# - Fonction d'activation : ReLu
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : 84.33%
# - Mean IoU : **47.04%**
# - Temps d'entrainement : **13m37s**
#
# <img src="data/images/U-Net_no-augmentation.png">

# %% [markdown]
# #### U-Net avec augmentation
#
# 🥉 **Excellent ratio score/temps**
#
# **Paramètres** :
#
# - Fonction d'activation : ELU
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : **85.01%**
# - Mean IoU : 46.98%
# - Temps d'entrainement : 15m08s
#
# <img src="data/images/U-Net_with-augmentation.png">

# %% [markdown]
# ### SegNet
#
# <img src="data/images/segnet.png" width='500'>
#
# Alors que dans un modèle U-Net, des cartes de caractéristiques entières sont transférées du chemin de compression au chemin d'expansion, ce qui nécessite beaucoup de mémoire. Dans Segnet, seuls les indice de pooling sont transférés vers le chemin d'expansion à partir du chemin de compression, utilisant moins de mémoire.
#
# SegNet est composé d'un réseau encodeur et d'un réseau décodeur correspondant, suivis d'une couche de classification finale par pixel. Cette architecture est illustrée dans le schéma ci-dessus. Le réseau encodeur est composé de 13 couches convolutionnelles qui correspondent aux 13 premières couches convolutionnelles du réseau VGG16 conçu pour la classification d'objets. Ils écartent les couches fully connected en faveur de la rétention de cartes de caractéristiques de plus haute résolution à la sortie la plus profonde de l'encodeur. Cela permet également de réduire considérablement le nombre de paramètres dans le réseau encodeur SegNet (de 134M à 14,7M) par rapport à d'autres architectures récentes. À chaque couche d'encodage correspond une couche de décodage et le réseau de décodage compte donc 13 couches. La sortie finale du décodeur est transmise à un classificateur soft-max multi-classes pour produire des probabilités de classe pour chaque pixel indépendamment.

# %% [markdown]
# #### SegNet sans augmentation
#
# **Paramètres** :
#
# - Fonction d'activation : ReLu
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : 86.47%
# - Mean IoU : 50.65%
# - Temps d'entrainement : **46m00s**
#
# <img src="data/images/SegNet_no-augmentation.png">

# %% [markdown]
# #### 🏆 SegNet avec augmentation
#
# 🥇 **Meilleur score/sécurité**
#
# **Paramètres** :
#
# - Fonction d'activation : ReLu
# - Optimiseur : Adam
# - Taux d'apprentissage : $ 10^{-4}$
#
# **Score** :
#
# - Pixel Accuracy : **87.49%**
# - Mean IoU : **51.67%**
# - Temps d'entrainement : 50m45s
#
# <img src="data/images/SegNet_with-augmentation.png">

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 13/18 : Plusieurs modèles ont été essayés en partant du plus simple vers les plus complexes</p>
# </div>

# %% [markdown]
# ### Résulat
#
# <img src="data/images/winner.png" width="150">
#
# Le modèle SegNet avec augmentation fournit de meilleurs résultats avec un **Pixel Accuracy de 87,49 %** et un **Mean IoU de 51,67 %**, mais un temps d’entrainement de 50 min 45 s
# En nous limitant à ces 3 critères, nous aurions pu largement être tentés de choisir le modèle U-Net sans augmentation de par son ratio score/temps qui surpasse le modèle SegNet. U-Net obtient un Pixel Accuracy de 84,33 %, un Mean IoU de 47,04 % pour **un temps d’entrainement de 13 min 37 s** seulement.
# Cependant, même si U-Net permettait **une économie de plus de 115 % sur le cloud** comparé à SegNet, en affinant la comparaison à l’aide de la matrice de confusion, SegNet a une efficacité de **détection des piétons supérieurs à 70 % comparé à U-Net**.
# SegNet affiche un Mean IoU de 50,57 % pour cette catégorie contre 23,32 % pour U-Net.
#
# Pour des raisons éthiques évidentes, la sécurité prime sur le budget et le temps.
# Les véhicules autonomes font plusieurs victimes tous les ans, comme on peut le vérifier sur ce site qui référence les décès causés par les Tesla : https://www.tesladeaths.com/
#
# Et pour citer Warren Buffett : « Une réputation se construit en 20 ans… mais se détruit en cinq minutes." »
#
# Donc **SegNet est parmi ces 3 modèles, le meilleur choix**. Dans l’étape suivante, il sera déployé sur Azure et exploitable avec une API Flask.

# %% [markdown]
# ___

# %% [markdown]
# <img src="data/images/agile.png" width="150">
#
# ## Déploiement
#
# Dans ce contexte, cette solution de déploiement est ponctuelle. À l’avenir, il est préférable de mettre en place un pipeline CI/CD afin d’améliorer le processus de développement.
#
# <img src="data/images/architecture.png">
#
# Microsoft fournit un tutoriel complet à ce sujet : https://docs.microsoft.com/fr-fr/azure/architecture/data-science-process/ci-cd-flask

# %%
from azureml.core import Workspace, Environment
from azureml.core.webservice import LocalWebservice
from azureml.core.model import InferenceConfig, Model

# Connect to workspace
ws = Workspace.from_config()
print("Workspace connected")

# Environment configuration
env = Environment.from_conda_specification(
    name='P8-ocia', file_path='data/deploy/env_azure_deploy.yml')
print("Environment configured")

# Deployment configuration
deployment_config = LocalWebservice.deploy_configuration(port=6789)
print("Deployment configured")

# Inference configuration
inference_config = InferenceConfig(source_directory='data/scripts',
                                   entry_script='predict.py',
                                   environment=env)
print("Inference configured")

# Deployment
model = Model(ws, config.model_name)
local_service = Model.deploy(ws, "ws-seg-local", [model], inference_config,
                             deployment_config)
print("Deployment configured")

local_service.wait_for_deployment()
# Out:
# Workspace connected
# Environment configured
# Deployment configured
# Inference configured
# Deployment configured
# myworkspace
# myresourcegroup
# westeurope
# fd158796-843a-8974-84c9-896a61d47e97
# Registering model ws-seg-local

# %% [markdown]
# <div class="alert alert-block alert-warning"><p><b>Mise à jour : </b> Le projet a été migré vers Heroku.</p>
# <p>Le site est accessible à <a href="https://future-vision-transport.herokuapp.com/" target="_blank">cette adresse</a> et son code source sur <a href="https://github.com/Abdess/Future-Vision-Transport-API" target="_blank">GitHub</a>.</p></div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 14/18 : Le modèle a été déployé grâce à une API Flask ou FastAPI</p>
#     <p>✅ 15/18 : Le modèle prend en entrée une image et retourne l’image des segments identifiés par le modèle (mask)</p>
# </div>

# %% [markdown]
# <img src="data/images/agenda.png" width="150">
#
# ## Note technique
#
# La note technique vous permet d’en savoir plus sur les détails de conception et les étapes de réflexion à la conception du projet.

# %%
# %%html
# <iframe width="900" height="500" src="Note_technique.pdf"></iframe>
# Out:
# <iframe width="900" height="500" src="Note_technique.pdf"></iframe>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>✅ 16/18 : une synthèse comparative des différents modèles a été rédigée dans la note technique (ex : tableau comparatif des résultats pour les différents modèles)</p>
#     <p>✅ 17/18 : le choix de la métrique d’évaluation a été explicité</p>
#     <p>✅ 18/18 : une synthèse comparative des améliorations de performance grâce aux différentes techniques utilisées a été rédigée dans la note technique</p>
# </div>

# %% [markdown]
# <img src="data/images/idea.png" width="150">
#
# ## Conclusion et axes d’amélioration
#
# Les scores des modèles sont encore très largement améliorables. Afin de diminuer les temps de calcul, le volume de données a volontairement était vu à la baisse en diminuant le nombre d’images et sa résolution. Donc en augmentant le nombre d’images et leur résolution nous pourrons, théoriquement, atteindre de meilleurs scores en plus d’affiner les hyperparamètres.
#
# Pour augmenter la sécurité, les prochaines augmentations d’images devront inclure plus de bruits relatifs au monde réel comme de la pluie ou de la neige par exemple, ou des glitchs pour reproduire des défaillances de la caméra ou encore des flous de mouvement qui sont par exemple proposés par la librairie imgaug à l’aide de la méthode imgcorruptlike. Pour aller plus loin, la librairie Albumentation propose la méthode AutoAlbument qui est un outil d’AutoML permettant de trouver les paramètres optimale pour l’augmentation.
#
# Les modèles sont entrainés à l’aide d’un transfert learning avec une architecture VGG16, néanmoins il existe des architectures plus récente et plus efficace comme ResNet ou DeepLabv3+ pour améliorer les performances.
#
# Pour trouver plus efficacement des paramètres optimaux, Cityscapes fournit une base de données de benchmarking à cette adresse : https://www.cityscapes-dataset.com/benchmarks/#scene-labeling-task
# Nous pouvons par exemple y trouver le code source d’un excellent modèle de segmentation de NVidia qui obtient un score IoU category de 93,2 %. Le code est disponible à cette adresse : https://github.com/NVIDIA/semantic-segmentation
#
# Pour finir, le pipeline peut être amélioré en mettant en place une architecture MLOps afin d’automatiser et augmenter la productivité.
#
# Comme pour chaque domaine de l'IA, la vision par ordinateur évolue très rapidement. Un système de veille actif est donc crucial pour constamment améliorer le produit.
